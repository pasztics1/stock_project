# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from main import DT,RF
from read_data import correct_format

#cd C:\Users\Surface\Desktop\binary_classifier_project

# %%
#set the rigth directory, it's now in the data folder
data = correct_file('features_AAPL.USUSD_Candlestick_1_M_ASK_11.10.2021-05.10.2024.csv') #https://numpy.org/devdocs/user/how-to-io.html
X = data.iloc[:, 1:-1].values #first row's not included, since it's date
y = data.iloc[:, -1].values
print(data.head())
# Out:
# File at c:\Users\Surface\Desktop\binary_classifier_project\data\labeled_features_AAPL.USUSD_Candlestick_1_M_ASK_11.10.2021-05.10.2024.csv already exists
#              Datetime  Open_BID  High_BID  Low_BID  Close_BID  Open_ASK  \
# 0 2021-10-11 13:49:00   143.786   143.957  143.717    143.947   143.814
# 1 2021-10-11 13:50:00   143.947   143.977  143.796    143.827   143.973
# 2 2021-10-11 13:51:00   143.797   143.797  143.596    143.707   143.823
# 3 2021-10-11 13:52:00   143.706   143.727  143.616    143.687   143.744
# 4 2021-10-11 13:53:00   143.677   143.877  143.677    143.866   143.703
#
#    High_ASK  Low_ASK  Close_ASK     Volume  ...  Support_10  Resistance_10  \
# 0   143.984  143.743    143.963  1980.0000  ...     142.977        143.984
# 1   144.003  143.823    143.843  2609.9999  ...     143.087        144.003
# 2   143.823  143.623    143.733  2440.0001  ...     143.306        144.003
# 3   143.754  143.643    143.703  2300.0000  ...     143.366        144.003
# 4   143.894  143.703    143.894  2069.9999  ...     143.366        144.003
#
#    Support_Close_10  Resistance_Close_10  Support_20  Resistance_20  \
# 0           143.145              143.955     141.796        143.984
# 1           143.310              143.955     141.856        144.003
# 2           143.400              143.955     141.906        144.003
# 3           143.400              143.955     142.376        144.003
# 4           143.490              143.955     142.546        144.003
#
#   Support_Close_20  Resistance_Close_20        RSI  Higher
# 0          141.885              143.955  80.000000   False
# 1          141.970              143.955  74.801061   False
# 2          142.535              143.955  82.456140    True
# 3          142.610              143.955  77.966102    True
# 4          142.610              143.955  77.891156   False
#
# [5 rows x 47 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)


clf = RF()
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)

def accuracy(y_test, y_pred):
    return np.sum(y_test == y_pred) / len(y_test)

    
acc = accuracy(y_test, predictions)
print(acc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)
#       4 clf = RF()
# ----> 5 clf.fit(X_train, y_train)
#       6 predictions = clf.predict(X_test)
#       8 def accuracy(y_test, y_pred):
#
# File c:\Users\Surface\Desktop\binary_classifier_project\main.py:156, in RF.fit(self, X, y)
#     150 tree = DT(max_depth=self.max_depth,
#     151    min_samples_split=self.min_samples_split,
#     152    n_features=self.n_features)
#     155 X_sample, y_sample = self._samples(X, y)
# --> 156 tree.fit(X_sample, y_sample)
#     157 print("Tree done!")
#     158 self.trees.append(tree)
#
# File c:\Users\Surface\Desktop\binary_classifier_project\main.py:39, in DT.fit(self, X, y)
#      36 def fit(self, X, y):
#      38     self.n_features = X.shape[1] if not self.n_features else min(X.shape[1],self.n_features) #making sure that the n_features do not exceed the num. of features that we have.
# ---> 39     self.root = self._grow_tree(X,y)
#
# File c:\Users\Surface\Desktop\binary_classifier_project\main.py:55, in DT._grow_tree(self, X, y, depth)
#      52 feat_idxs = np.random.choice(n_feats, self.n_features, replace=False) #https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html
#      54 #best split based on IG
# ---> 55 best_feature, best_thresh = self._best_split(X, y, feat_idxs) #feat_idx is the features I want to include when creating a new split, that's where randomness is created
#      58 #create child nodes
#      59 left_idxs, right_idxs = self._split(X[:, best_feature],best_thresh)
#
# File c:\Users\Surface\Desktop\binary_classifier_project\main.py:76, in DT._best_split(self, X, y, feat_idxs)
#      71 thresholds = np.unique(X_column)
#      73 for thr in thresholds:
#      74     #calc. IG
# ---> 76     gain = self._info_gain(y, X_column, thr)
#      78     if gain > best_gain:
#      79         best_gain = gain
#
# File c:\Users\Surface\Desktop\binary_classifier_project\main.py:90, in DT._info_gain(self, y, X_column, threshold)
#      88 parent_entropy = self._entropy(y)
#      89 #create children
# ---> 90 left_idxs, right_idxs = self._split(X_column, threshold)
#      91 if len(left_idxs) == 0 or len(right_idxs) == 0:
#      92     return 0
#
# File c:\Users\Surface\Desktop\binary_classifier_project\main.py:108, in DT._split(self, X_coulmn, split_thresh)
#     106 def _split(self, X_coulmn, split_thresh):
#     107     left_idxs = np.argwhere(X_coulmn<=split_thresh).flatten() #as in excel, and flatten makes an n dimensional list "flat", so 1d
# --> 108     right_idxs = np.argwhere(X_coulmn>split_thresh).flatten()
#     109     return left_idxs, right_idxs
#
# File c:\Users\Surface\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\numeric.py:561, in argwhere(a)
#     557 def _argwhere_dispatcher(a):
#     558     return (a,)
# --> 561 @array_function_dispatch(_argwhere_dispatcher)
#     562 def argwhere(a):
#     563     """
#     564     Find the indices of array elements that are non-zero, grouped by element.
#     565
#    (...)
#     601
#     602     """
#     603     # nonzero does not behave well on 0d, so promote to 1d
#
# KeyboardInterrupt:
