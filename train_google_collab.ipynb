# %%
"""
function preventTimeout() {
  setInterval(function() {
    document.querySelector("colab-toolbar-button").click();
  }, 60000); // Clicks the toolbar every 60 seconds to prevent timeout.
}
preventTimeout();
"""

#stop
"""
var interval_id = window.setInterval(function(){}, 9999);
while (interval_id--) {
  window.clearInterval(interval_id);
}
"""

#Ctrl+shift+i

# %%
username = "pasztics1"
token = "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"
# !git clone https://{username}:{token}@github.com/pasztics1/stock_project.git

# %cd stock_project
#ctr alt enter - start cell


import os
path = os.path.join(os.getcwd(), "data")

from google.colab import files

from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import pickle


from main import RF,RF_boosted
from feature_engineering import add_features
from read_data import correct_format

#hyperparams
PERC_DATA_USED = 0.05

#initializing file names for i/o
ask_file_name = "AAPL.USUSD_Candlestick_1_M_ASK_11.10.2021-05.10.2024.csv"
bid_file_name = "AAPL.USUSD_Candlestick_1_M_BID_11.10.2021-05.10.2024.csv"
features_name = f'features_{PERC_DATA_USED}{ask_file_name}'
# Out:
# Cloning into 'stock_project'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 123 (delta 52), reused 89 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 7.89 MiB | 15.69 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# /content/stock_project/stock_project

# %%
#adding feature engineering to our data if it doesn't exist
if not os.path.isfile(os.path.join(path,features_name)):
    add_features(ask_file_name,bid_file_name,PERC_DATA_USED)
else:
    print(f"{features_name} already exists!")

#https://numpy.org/devdocs/user/how-to-io.html
data = correct_format(features_name)

X = data.iloc[:, 1:-1].values #first row's not included, since it's date
y = data.iloc[:, -1].values

X = X.astype(np.float64)
y = y.astype(np.int64)



#splitting the data into training and test portions
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)
# Out:
# File at /content/stock_project/stock_project/data/labeled_AAPL.USUSD_Candlestick_1_M_BID_11.10.2021-05.10.2024.csv already exists
# File at /content/stock_project/stock_project/data/labeled_AAPL.USUSD_Candlestick_1_M_ASK_11.10.2021-05.10.2024.csv already exists
#               Datetime  Open_BID  High_BID  Low_BID  Close_BID  Open_ASK  \
# 19 2021-10-11 13:49:00   143.786   143.957  143.717    143.947   143.814
# 20 2021-10-11 13:50:00   143.947   143.977  143.796    143.827   143.973
# 21 2021-10-11 13:51:00   143.797   143.797  143.596    143.707   143.823
# 22 2021-10-11 13:52:00   143.706   143.727  143.616    143.687   143.744
# 23 2021-10-11 13:53:00   143.677   143.877  143.677    143.866   143.703
#
#     High_ASK  Low_ASK  Close_ASK     Volume  ...  Support_10  Resistance_10  \
# 19   143.984  143.743    143.963  1980.0000  ...     142.977        143.984
# 20   144.003  143.823    143.843  2609.9999  ...     143.087        144.003
# 21   143.823  143.623    143.733  2440.0001  ...     143.306        144.003
# 22   143.754  143.643    143.703  2300.0000  ...     143.366        144.003
# 23   143.894  143.703    143.894  2069.9999  ...     143.366        144.003
#
#     Support_Close_10  Resistance_Close_10  Support_20  Resistance_20  \
# 19           143.145              143.955     141.796        143.984
# 20           143.310              143.955     141.856        144.003
# 21           143.400              143.955     141.906        144.003
# 22           143.400              143.955     142.376        144.003
# 23           143.490              143.955     142.546        144.003
#
#    Support_Close_20  Resistance_Close_20        RSI  Higher
# 19          141.885              143.955  80.000000   False
# 20          141.970              143.955  74.801061   False
# 21          142.535              143.955  82.456140    True
# 22          142.610              143.955  77.966102    True
# 23          142.610              143.955  77.891156   False
#
# [5 rows x 47 columns]
# File at /content/stock_project/stock_project/data/labeled_features_AAPL.USUSD_Candlestick_1_M_ASK_11.10.2021-05.10.2024.csv already exists
#              Datetime  Open_BID  High_BID  Low_BID  Close_BID  Open_ASK  \
# 0 2024-09-16 13:46:00   215.017   215.187  214.777    214.777   215.083
# 1 2024-09-16 13:47:00   214.757   215.217  214.696    215.136   214.793
# 2 2024-09-16 13:48:00   215.137   215.286  215.076    215.227   215.183
# 3 2024-09-16 13:49:00   215.216   215.887  215.216    215.447   215.264
# 4 2024-09-16 13:50:00   215.436   215.607  215.316    215.507   215.504
#
#    High_ASK  Low_ASK  Close_ASK     Volume  ...  Support_10  Resistance_10  \
# 0   215.243  214.823    214.823  1970.0000  ...     214.147        215.524
# 1   215.273  214.744    215.204  1910.0000  ...     214.386        215.524
# 2   215.334  215.153    215.263  1760.0000  ...     214.696        215.524
# 3   215.933  215.254    215.503  2250.0000  ...     214.696        215.933
# 4   215.654  215.393    215.553  2089.9999  ...     214.696        215.933
#
#    Support_Close_10  Resistance_Close_10  Support_20  Resistance_20  \
# 0             214.4              215.260     213.907        222.544
# 1             214.8              215.260     213.907        222.544
# 2             214.8              215.260     213.907        222.504
# 3             214.8              215.475     213.907        216.904
# 4             214.8              215.530     213.907        216.584
#
#   Support_Close_20  Resistance_Close_20        RSI  Higher
# 0          214.185              222.470  42.630058    True
# 1          214.185              222.460  66.366906    True
# 2          214.185              222.455  66.123188    True
# 3          214.185              216.300  68.624161    True
# 4          214.185              216.115  73.555166    True
#
# [5 rows x 47 columns]

# %%
#training the data
clf = RF_boosted()
clf.fit(X_train, y_train)
# Out:
# Tree done!
# Tree done!
# Tree done!
# Tree done!
# Tree done!

# %%
#Saving model parameters
with open(f'save_model.pkl', 'wb') as f:
    pickle.dump(clf, f)

# %%
files.download('save_model.pkl')
